# %%
import seaborn as sns
import matplotlib.pyplot as plt
titanic_df = sns.load_dataset('titanic')
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Plot a box plot for distribution of age with respect to each gender along with the information about whether they survived or not.
sns.boxplot(data=titanic_df,x='age',y='sex',hue='survived')
plt.title('Age Distribution by gender and survival')
plt.show()

# %%
Observations:

1. The median age for male passengers who survived was lower than that of female passengers who survived.
    The age distribution for male passengers who did not survive was wider than that of male passengers who survived.
2. The age distribution for female passengers who did not survive was wider than that of female passengers who survived.
3. There were some outliers in the age distribution for both male and female passengers who did not survive.
4. Overall, there appears to be a slight difference in the age distribution between male and female passengers who survived,
    with female passengers generally being older. However, the age distribution for both genders is similar for passengers who did not survive.
